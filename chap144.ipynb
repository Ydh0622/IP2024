# %% [markdown]
# ##### 1.4.4 Smoothing Images

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ##### 2DConvolution(ImageFiltering)

# %%
img = cv2.imread('DOGe.jpg')

kernel = np.ones((5,5),np.float32)/25
dst = cv2.filter2D(img,-1,kernel)
    
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]),plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# ##### 1. Averaging

# %%
img = cv2.imread('DOGe.jpg')
blur = cv2.blur(img,(5,5))
 
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])

# %% [markdown]
# ##### 2. Gaussian Filtering

# %%
img = cv2.imread('DOGe.jpg')

# blur3 = cv2.blur(img,(3,3))
blur5 = cv2.blur(img,(5,5))
# blur3 = cv2.GaussianBlur(img,(5,5),0)
# GaussianBlur5 = cv2.GaussianBlur(img,(15,15),0)
# medianBlur5 = cv2.medianBlur(img,15)
BilateralFilter= cv2.bilateralFilter(img,9,75,75)

plt.subplot(121),plt.imshow(blur5),plt.title('blur5')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(BilateralFilter),plt.title('bilateralFilter')
plt.xticks([]), plt.yticks([])
plt.show()
